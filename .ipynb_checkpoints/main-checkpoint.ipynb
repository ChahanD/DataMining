# %%
import os
import time
import urllib.request
from SPARQLWrapper import SPARQLWrapper, JSON
from urllib.error import HTTPError

endpoint_url = "https://query.wikidata.org/sparql"
img_data = {}
image_counter = 0  # Compteur global pour le nom des images

# Requête pour récupérer les infos de l'entité donnée - Q144/Chien par défaut
def query(wd='Q144', limit=5):
    return f"""SELECT ?item ?itemLabel ?pic
                WHERE {{
                  # ?item wdt:P31 wd:{wd}.
                  # ?item wdt:P18 ?pic.
                  SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
                }}
                LIMIT {limit}"""

def get_results(endpoint_url, query):
    user_agent = 'MaximeCornaton/0.0 (https://github.com/MaximeCornaton/CPE_Data_Mining; maxime.cornaton@cpe.fr)'
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    
    # Boucle de tentative en cas d'erreur 429 Too Many Requests
    for i in range(3):
        try:
            return sparql.query().convert()
        except HTTPError as e:
            if e.response.status_code == 429:
                retry_after = int(e.response.headers.get('Retry-After', '90'))
                print(f"Too Many Requests. Tentative dans {retry_after} secondes.")
                sleep(retry_after)
            else:
                raise e
    
    raise Exception("Nombre maximum de tentatives pour atteindre Wikidata atteint.")

# Pour créer le dossier des images s'il n'existe pas
def createFolder(name='images'):
    if name not in os.listdir():
        os.mkdir(name)
    else:
        print('Dossier '+name+' déjà existant !')

# Pour vérifier si un dossier est vide - évitons de retélécharger des images inutilement.
def isEmpty(name='images'):
    if len(os.listdir(name)) == 0:
        return True
    return False

# Pour ajouter des éléments à la bdd avec la mise en place d'un compteur pour chaque image 
def addImg(wd, limit):
    global image_counter  # Référence au compteur global
    results = get_results(endpoint_url, query(wd, limit))
    for result in results['results']['bindings']:
        image_counter += 1  # Incrémente le compteur pour chaque image
        name_img = f'image{image_counter}'  # Nom basé sur la position dans la liste des téléchargements

        img_data[name_img] = {}
        downloadImage(result['pic']['value'], name_img)

# Ajoute les images de toutes les entités spécifiées
def addAllImg(wd, limit):
    for w in wd:
        addImg(w, limit)

# Pour télécharger l'image d'un élément de la bdd
def downloadImage(url, name_img='img0'):
    full_path = 'images/' + name_img + '.jpg'
    urllib.request.urlretrieve(url, full_path)
    time.sleep(1)

# Si les images sont déjà téléchargées on initialise le tableau
def initAlreadyDownload(namefolder='images'):
    for image in os.listdir(namefolder):
        #img_data[image.split(".")[0]] = {'image': ""}
        img_data[image.split(".")[0]] = {}

# Pour télécharger toutes les images - limit par query
def downloadAllImages(wd=['Q144'], limit=5):
    createFolder()
    if not isEmpty():
        print('Images déjà téléchargées !')
        initAlreadyDownload()
        return False
    addAllImg(wd, limit)
    return True 

#Supprimer une image du dossier 
def removeImage(image):
    if os.path.isfile('images/'+image):
        os.remove('images/'+image)
        img_data.pop(image.split(".")[0])
    else:
        shutil.rmtree('images/'+image)
        
bdd = ['Q144','Q14660','Q23442','Q28803'] #Chien, drapeau, ile, sandwich
downloadAllImages(wd=bdd,limit=30)
print(img_data)

# %%
#Fonction pour extraire et enregistrer diverses métadonnées d'une image dans le dictionnaire img_data.
def getMetaImg(name, imgfile):
    #clés Exif
    DATE_KEY = 36867
    MODEL_KEY = 272
    
    img_data[name].update({
        'size': getSizeImg(imgfile.size),
        'orientation': getOrientationImg(imgfile.size),
        'format': imgfile.format,
    })
    
    #getColorsImg(name, imgfile)
    
    exif_data = imgfile._getexif()
    if exif_data is not None:
        if DATE_KEY in exif_data:
            img_data[name]['date'] = exif_data[DATE_KEY]
        if MODEL_KEY in exif_data:
            img_data[name]['model'] = exif_data[MODEL_KEY]
            
# met à jour le dictionnaire img_data pour l'image spécifiée avec son size, orientation, et format. 
def getOrientationImg(size): #(largeur,hauteur)
    width,height = size
    return "landscape" if width > height else "portrait" if height > width else "squared"

#classe la taille de l'image en "large", "medium", ou "small" basé sur la comparaison de sa résolution (largeur x hauteur) avec des seuils prédéfinis.

def getSizeImg(size): #(largeur,hauteur)
    width,height = size
    return "large" if width*height>1920*1080 else "small" if width*height<640*480 else "medium"

def getColorsImg(name, imgfile, cluster_nbr=2, n_init=1):
    
    img_data[name]['colors'] = []
    
    # Redimensionner l'image pour accélérer le traitement
    imgfile = imgfile.resize((int(imgfile.size[0]/2), int(imgfile.size[1]/2)))

    # Convertir l'image en un tableau numpy
    img_array = np.array(imgfile)
    
    try:
        img_vector = img_array.reshape(-1, 3)

        clusters = MiniBatchKMeans(n_clusters=cluster_nbr, n_init=n_init, random_state=69).fit(img_vector) #Random state pour garder la meme seed ppour toutes les images

        for i, center in enumerate(clusters.cluster_centers_):
            rgb = tuple(map(int, center))
        

            img_data[name]['colors'].append(rgb)
            
    except Exception as e:
        print('Pas de couleur : {}'.format(e))
        #img_data[name]['colors'] = [-1]

def RGBtoName(rgb):
    # chercher le nom de couleur correspondant au code RGB
    try:
        color_name = webcolors.rgb_to_name(rgb)
    except ValueError:
        # si le nom exact n'est pas trouvé, trouver le nom le plus proche
        min_colors = {}
        for key, name_ in webcolors.CSS3_HEX_TO_NAMES.items():
            r_c, g_c, b_c = webcolors.hex_to_rgb(key)
            rd = (r_c - rgb[0]) ** 2
            gd = (g_c - rgb[1]) ** 2
            bd = (b_c - rgb[2]) ** 2
            min_colors[(rd + gd + bd)] = name_
        color_name = min_colors[min(min_colors.keys())]
    return color_name

def openImgGetMeta(name): #name = 'img.jpg'
    try:
        with Image.open("images/"+name) as imgfile:
            #print(imgfile.size, imgfile.format)
            name = name.split(".")[0]
            getMetaImg(name, imgfile)

        imgfile.close()
        return True
    except FileNotFoundError as e:
        print('Impossible de trouver le fichier {}: {}'.format("images/"+name, e))
        return False
    except Exception as e:
        print('Erreur lors de l\'ouverture de l\'image {}: {}'.format("images/"+name, e))
        removeImage(name)
        return False
        
#Obtenir les metas de toutes nos images    
def openGetMetaAllImg(namefolder='images'):
    # Commencer par 'image1' et augmenter le numéro jusqu'à ce qu'une image n'existe pas
    i = 1
    while True:
        img_name = f'image{i}.jpg'  # Format séquentiel du nom de fichier
        img_path = os.path.join(namefolder, img_name)

        if not os.path.isfile(img_path):
            break  # Sortir de la boucle si le fichier n'existe pas

        with Image.open(img_path) as imgfile:
            getMetaImg(img_name, imgfile)  # Extraction des métadonnées

            # Afficher les métadonnées extraites
            print(f"Métadonnées pour {img_name}: {img_data[img_name]}")

        i += 1

openGetMetaAllImg()
# Out:
# Erreur lors de l'ouverture de l'image images/image1.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image10.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image100.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image101.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image102.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image103.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image104.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image105.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image106.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image107.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image108.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image109.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image11.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image110.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image12.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image13.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image14.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image15.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image16.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image17.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image18.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image19.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image2.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image20.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image21.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image22.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image23.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image24.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image25.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image26.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image27.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image28.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image29.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image3.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image30.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image31.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image32.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image33.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image34.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image35.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image36.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image37.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image38.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image39.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image4.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image40.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image41.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image42.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image43.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image44.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image45.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image46.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image47.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image48.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image49.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image5.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image50.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image51.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image52.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image53.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image54.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image55.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image56.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image57.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image58.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image59.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image6.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image60.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image61.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image62.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image63.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image64.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image65.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image66.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image67.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image68.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image69.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image7.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image70.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image71.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image72.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image73.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image74.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image75.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image76.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image77.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image78.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image79.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image8.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image80.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image81.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image82.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image83.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image84.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image85.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image86.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image87.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image88.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image89.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image9.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image90.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image91.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image92.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image93.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image94.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image95.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image96.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image97.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image98.jpg: name 'Image' is not defined
# Erreur lors de l'ouverture de l'image images/image99.jpg: name 'Image' is not defined
