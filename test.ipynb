# %%
import requests
from SPARQLWrapper import SPARQLWrapper, JSON
from PIL import Image, ExifTags
from io import BytesIO
import os
import json
import time

# Créer les dossiers pour les images et les métadonnées
os.makedirs('images', exist_ok=True)
os.makedirs('metadata', exist_ok=True)

# Définir l'endpoint SPARQL de Wikidata et la requête
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql_query = """
SELECT ?image
WHERE {
  {
    # ?item wdt:P31 wd:Q1074; # éléments qui sont des paysages
    wdt:P18 ?image.
  } UNION {
    # ?item wdt:P31 wd:Q1420; # éléments qui sont des voitures
    wdt:P18 ?image.
  } UNION {
    # ?item wdt:P31 wd:Q31629; # éléments qui sont des sports
    wdt:P18 ?image.
  } UNION {
    # ?item wdt:P31 wd:Q3305213; # éléments qui sont des œuvres d'art
    wdt:P18 ?image.
  }
}
LIMIT 100
"""
sparql.setQuery(sparql_query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# Télécharger les images et enregistrer les métadonnées
for i, result in enumerate(results["results"]["bindings"]):
    image_url = result["image"]["value"]
    try:
        headers = {'User-Agent': 'Votre User-Agent ici'}
        response = requests.get(image_url, headers=headers)
        if response.status_code == 200:
            image_path = f'images/image_{i}.jpg'
            with open(image_path, 'wb') as file:
                file.write(response.content)

            image = Image.open(BytesIO(response.content))
            metadata = image._getexif()

            if metadata:
                formatted_metadata = {}
                for tag, value in metadata.items():
                    decoded_tag = ExifTags.TAGS.get(tag, tag)
                    if isinstance(value, bytes):
                        value = value.decode('utf-8', 'ignore')  # Convertir les bytes en string
                    formatted_metadata[decoded_tag] = value

                metadata_path = f'metadata/metadata_{i}.json'
                with open(metadata_path, 'w') as file:
                    json.dump(formatted_metadata, file, ensure_ascii=False, indent=4)
            else:
                print(f"Pas de métadonnées EXIF pour l'image {i}")

            print(f"Image {i} téléchargée avec succès.")
        else:
            print(response.status_code)
            print(image_url)  
    except Exception as e:
        print(f"Erreur lors du téléchargement de l'image {i}: {e}")
# Out:
# Pas de métadonnées EXIF pour l'image 0
# Image 0 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 1
# Image 1 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 2: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 3: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 4
# Image 4 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 5: Object of type bytes is not JSON serializable
# Erreur lors du téléchargement de l'image 6: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 7: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 8
# Image 8 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 9
# Image 9 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 10
# Image 10 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 11
# Image 11 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 12
# Image 12 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 13: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 14: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 15: Object of type bytes is not JSON serializable
# Erreur lors du téléchargement de l'image 16: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 17: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 18
# Image 18 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 19: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 20: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 21: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 22: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 23: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 24: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 25: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 26: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 27
# Image 27 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 28: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 29: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 30: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 31: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 32
# Image 32 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 33
# Image 33 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 34: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 35: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 36: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 37: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 38: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 39: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 40: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 41: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 42: Object of type bytes is not JSON serializable
# Erreur lors du téléchargement de l'image 43: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 44
# Image 44 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 45: Object of type bytes is not JSON serializable
# Image 46 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 47
# Image 47 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 48: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 49: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 50
# Image 50 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 51: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 52: Object of type bytes is not JSON serializable
# Erreur lors du téléchargement de l'image 53: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 54: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 55: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 56
# Image 56 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 57: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 58
# Image 58 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 59: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 60: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 61
# Image 61 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 62
# Image 62 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 63
# Image 63 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 64
# Image 64 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 65
# Image 65 téléchargée avec succès.
# Image 66 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 67: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 68
# Image 68 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 69
# Image 69 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 70: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 71: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 72: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 73: Object of type IFDRational is not JSON serializable
# Image 74 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 75: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 76: Object of type IFDRational is not JSON serializable
# Image 77 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 78: Object of type bytes is not JSON serializable
# Image 79 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 80
# Image 80 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 81: Object of type IFDRational is not JSON serializable
# Erreur lors du téléchargement de l'image 82: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 83
# Image 83 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 84: 'charmap' codec can't encode character '\x97' in position 80: character maps to <undefined>
# Pas de métadonnées EXIF pour l'image 85
# Image 85 téléchargée avec succès.
# Image 86 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 87: Object of type bytes is not JSON serializable
# Erreur lors du téléchargement de l'image 88: Image size (226536844 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
# Erreur lors du téléchargement de l'image 89: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 90
# Image 90 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 91: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 92
# Image 92 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 93: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 94
# Image 94 téléchargée avec succès.
# Erreur lors du téléchargement de l'image 95: Object of type IFDRational is not JSON serializable
# C:\Users\chaha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\PIL\Image.py:3074: DecompressionBombWarning: Image size (175214016 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Erreur lors du téléchargement de l'image 96: Object of type IFDRational is not JSON serializable
# Pas de métadonnées EXIF pour l'image 97
# Image 97 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 98
# Image 98 téléchargée avec succès.
# Pas de métadonnées EXIF pour l'image 99
# Image 99 téléchargée avec succès.
